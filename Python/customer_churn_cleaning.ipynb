# %%
import pandas as pd 
import numpy as np

# %%
df = pd.read_excel(r"C:\Users\Soyanshu\Downloads\Telco_customer_churn.xlsx\Telco_customer_churn.xlsx")
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# ...

# %%
df.shape
# Out:
# (7043, 33)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 33 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   CustomerID         7043 non-null   object
#  1   Count              7043 non-null   int64
#  2   Country            7043 non-null   object
#  3   State              7043 non-null   object
#  4   City               7043 non-null   object
#  5   Zip Code           7043 non-null   int64
#  6   Lat Long           7043 non-null   object
#  7   Latitude           7043 non-null   float64
#  8   Longitude          7043 non-null   float64
#  9   Gender             7043 non-null   object
#  10  Senior Citizen     7043 non-null   object
#  11  Partner            7043 non-null   object
#  12  Dependents         7043 non-null   object
#  13  Tenure Months      7043 non-null   int64
#  14  Phone Service      7043 non-null   object
#  15  Multiple Lines     7043 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges           0
# Churn Label             0
# Churn Value             0
# Churn Score             0
# CLTV                    0
# Churn Reason         5174
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.head(2)
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# 0      No         No              2           Yes             No
# 1      No        Yes              2           Yes             No
#
#   Internet Service Online Security Online Backup Device Protection  \
# 0              DSL             Yes           Yes                No
# 1      Fiber optic              No            No                No
#
#   Tech Support Streaming TV Streaming Movies        Contract  \
# 0           No           No               No  Month-to-month
# ...

# %%
df['Churn Label'].value_counts()
# Out:
# Churn Label
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df['Churn Label'].value_counts(normalize=True)*100
# Out:
# Churn Label
# No     73.463013
# Yes    26.536987
# Name: proportion, dtype: float64

# %%
df['Contract'].value_counts()
# Out:
# Contract
# Month-to-month    3875
# Two year          1695
# One year          1473
# Name: count, dtype: int64

# %%
df['Internet Service'].value_counts()
# Out:
# Internet Service
# Fiber optic    3096
# DSL            2421
# No             1526
# Name: count, dtype: int64

# %%
df['Payment Method'].value_counts()
# Out:
# Payment Method
# Electronic check             2365
# Mailed check                 1612
# Bank transfer (automatic)    1544
# Credit card (automatic)      1522
# Name: count, dtype: int64

# %%
df['Total Charges'].head()
# Out:
# 0     108.15
# 1     151.65
# 2      820.5
# 3    3046.05
# 4     5036.3
# Name: Total Charges, dtype: object

# %%
df['Total Charges']=pd.to_numeric(df['Total Charges'],errors='coerce')
df['Total Charges'].dtype
# Out:
# dtype('float64')

# %%
df['Total Charges'].isnull().sum()
# Out:
# np.int64(11)

# %%
df.isnull().sum()
# Out:
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges          11
# Churn Label             0
# Churn Value             0
# Churn Score             0
# CLTV                    0
# Churn Reason         5174
# dtype: int64

# %%
df['Total Charges']=df['Total Charges'].fillna(0)

# %%
df.isnull().sum()
# Out:
# CustomerID              0
# Count                   0
# Country                 0
# State                   0
# City                    0
# Zip Code                0
# Lat Long                0
# Latitude                0
# Longitude               0
# Gender                  0
# Senior Citizen          0
# Partner                 0
# Dependents              0
# Tenure Months           0
# Phone Service           0
# Multiple Lines          0
# Internet Service        0
# Online Security         0
# Online Backup           0
# Device Protection       0
# Tech Support            0
# Streaming TV            0
# Streaming Movies        0
# Contract                0
# Paperless Billing       0
# Payment Method          0
# Monthly Charges         0
# Total Charges           0
# Churn Label             0
# Churn Value             0
# Churn Score             0
# CLTV                    0
# Churn Reason         5174
# dtype: int64

# %%
df.describe()
# Out:
#         Count      Zip Code     Latitude    Longitude  Tenure Months  \
# count  7043.0   7043.000000  7043.000000  7043.000000    7043.000000
# mean      1.0  93521.964646    36.282441  -119.798880      32.371149
# std       0.0   1865.794555     2.455723     2.157889      24.559481
# min       1.0  90001.000000    32.555828  -124.301372       0.000000
# 25%       1.0  92102.000000    34.030915  -121.815412       9.000000
# 50%       1.0  93552.000000    36.391777  -119.730885      29.000000
# 75%       1.0  95351.000000    38.224869  -118.043237      55.000000
# max       1.0  96161.000000    41.962127  -114.192901      72.000000
#
#        Monthly Charges  Total Charges  Churn Value  Churn Score         CLTV
# count      7043.000000    7043.000000  7043.000000  7043.000000  7043.000000
# mean         64.761692    2279.734304     0.265370    58.699418  4400.295755
# std          30.090047    2266.794470     0.441561    21.525131  1183.057152
# ...

# %%
df.describe(include='all')
# Out:
#         CustomerID   Count        Country       State         City  \
# count         7043  7043.0           7043        7043         7043
# unique        7043     NaN              1           1         1129
# top     3186-AJIEK     NaN  United States  California  Los Angeles
# freq             1     NaN           7043        7043          305
# mean           NaN     1.0            NaN         NaN          NaN
# std            NaN     0.0            NaN         NaN          NaN
# min            NaN     1.0            NaN         NaN          NaN
# 25%            NaN     1.0            NaN         NaN          NaN
# 50%            NaN     1.0            NaN         NaN          NaN
# 75%            NaN     1.0            NaN         NaN          NaN
# max            NaN     1.0            NaN         NaN          NaN
#
#             Zip Code                Lat Long     Latitude    Longitude Gender  \
# count    7043.000000                    7043  7043.000000  7043.000000   7043
# ...

# %%
df.groupby('Churn Label').size()
# Out:
# Churn Label
# No     5174
# Yes    1869
# dtype: int64

# %%
df[['Monthly Charges','Total Charges','CLTV']].describe()
# Out:
#        Monthly Charges  Total Charges         CLTV
# count      7043.000000    7043.000000  7043.000000
# mean         64.761692    2279.734304  4400.295755
# std          30.090047    2266.794470  1183.057152
# min          18.250000       0.000000  2003.000000
# 25%          35.500000     398.550000  3469.000000
# 50%          70.350000    1394.550000  4527.000000
# 75%          89.850000    3786.600000  5380.500000
# max         118.750000    8684.800000  6500.000000

# %%
df.head()
# Out:
#    CustomerID  Count        Country       State         City  Zip Code  \
# 0  3668-QPYBK      1  United States  California  Los Angeles     90003
# 1  9237-HQITU      1  United States  California  Los Angeles     90005
# 2  9305-CDSKC      1  United States  California  Los Angeles     90006
# 3  7892-POOKP      1  United States  California  Los Angeles     90010
# 4  0280-XJGEX      1  United States  California  Los Angeles     90015
#
#                  Lat Long   Latitude   Longitude  Gender Senior Citizen  \
# 0  33.964131, -118.272783  33.964131 -118.272783    Male             No
# 1   34.059281, -118.30742  34.059281 -118.307420  Female             No
# 2  34.048013, -118.293953  34.048013 -118.293953  Female             No
# 3  34.062125, -118.315709  34.062125 -118.315709  Female             No
# 4  34.039224, -118.266293  34.039224 -118.266293    Male             No
#
#   Partner Dependents  Tenure Months Phone Service Multiple Lines  \
# ...

# %%
df.groupby('Churn Label')['Monthly Charges'].mean()
# Out:
# Churn Label
# No     61.265124
# Yes    74.441332
# Name: Monthly Charges, dtype: float64

# %%
df['Charge Group'] = pd.cut(
    df['Monthly Charges'],
    bins=[0,30,60,90,120],
    labels=['0-30','31-60','61-90','91-120']
)

# %%
df.groupby('Charge Group')['Churn Value'].mean()*100
# Out:
# C:\Users\Soyanshu\AppData\Local\Temp\ipykernel_5832\2315844930.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Charge Group')['Churn Value'].mean()*100
# Charge Group
# 0-30       9.800363
# 31-60     25.928854
# 61-90     33.906119
# 91-120    32.777458
# Name: Churn Value, dtype: float64

# %%
df.groupby('Contract')['Churn Value'].mean()*100
# Out:
# Contract
# Month-to-month    42.709677
# One year          11.269518
# Two year           2.831858
# Name: Churn Value, dtype: float64

# %%
df['Tenure Group'] = pd.cut(
    df['Tenure Months'],
    bins=[0,12,24,48,72],
    labels=[
        '0-12 Months',
        '13-24 Months',
        '25-48 Months',
        '49-72 Months'
    ],
    include_lowest=True
)

# %%
df.groupby('Tenure Group')['Churn Value'].mean()*100
# Out:
# C:\Users\Soyanshu\AppData\Local\Temp\ipykernel_5832\3875742741.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   df.groupby('Tenure Group')['Churn Value'].mean()*100
# Tenure Group
# 0-12 Months     47.438243
# 13-24 Months    28.710938
# 25-48 Months    20.388959
# 49-72 Months     9.513176
# Name: Churn Value, dtype: float64

# %%
df['Churn Reason'].value_counts().head(10)
# Out:
# Churn Reason
# Attitude of support person                   192
# Competitor offered higher download speeds    189
# Competitor offered more data                 162
# Don't know                                   154
# Competitor made better offer                 140
# Attitude of service provider                 135
# Competitor had better devices                130
# Network reliability                          103
# Product dissatisfaction                      102
# Price too high                                98
# Name: count, dtype: int64

# %%
df.groupby('Internet Service')['Churn Value'].mean()*100
# Out:
# Internet Service
# DSL            18.959108
# Fiber optic    41.892765
# No              7.404980
# Name: Churn Value, dtype: float64

# %%
df['Churn Reason'] = df['Churn Reason'].fillna('Not Churned')

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\Soyanshu'

# %%
import os
'customer_churn_cleaned.csv' in os.listdir()
# Out:
# True

# %%
df.to_csv('customer_churn_cleaned.csv', index=False)

# %%
df['Total Charges'].isnull().sum()
# Out:
# np.int64(11)

# %%
df.isnull().sum()[df.isnull().sum() > 0]
# Out:
# Series([], dtype: int64)

# %%
df['Total Charges'].dtype
# Out:
# dtype('float64')

# %%
df.to_csv('customer_churn_cleaned.csv', index=False)

# %%
df['Total Charges'].dtype
# Out:
# dtype('float64')
